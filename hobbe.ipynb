# %% [markdown]
# # 🚀 Hobbe Notebook
#
# This is a sample notebook connected to GitHub.
#
# - Test code
# - Experiments
# - Future ideas

# %%
# Basic test
print("Hello from Colab + GitHub 🚀")

# %%
# Simple calculation
a = 5
b = 10
print("Sum:", a + b)
