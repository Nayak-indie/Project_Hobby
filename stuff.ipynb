# %% [markdown]
# <a href="https://colab.research.google.com/github/Nayak-indie/Project_Hobby/blob/main/stuff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello GitHub 🚀")
# Out:
# Hello GitHub 🚀
